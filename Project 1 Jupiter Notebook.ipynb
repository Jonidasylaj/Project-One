# %%
# Import pandas and matplotlib for data visualisation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import data from csv. The first data is the title.basics file
df_title=pd.read_csv('Documents/Project One/Data/title.basics.csv')

# %%
# Below we can have the first 5 rows of the data frame
df_title.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# Check the dimension of data frames in columns and rows
df_title.shape
# Out:
# (146144, 6)

# %%
# Check if we have duplicates in our data frame
df_title.duplicated().value_counts()
# Out:
# False    146144
# Name: count, dtype: int64

# %%
# Below will show the concise summary of data frame
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#lets split the names of genres
lst_col = 'genres' 
df_x = df.assign(**{lst_col:df[lst_col].str.split(',')})
df_x
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                    genres
# 0                 175.0    [Action, Crime, Drama]
# 1                 114.0        [Biography, Drama]
# 2                 122.0                   [Drama]
# 3                   NaN           [Comedy, Drama]
# 4                  80.0  [Comedy, Drama, Fantasy]
# ...                 ...                       ...
# 146139            123.0                   [Drama]
# 146140              NaN             [Documentary]
# 146141              NaN                  [Comedy]
# 146142            116.0                       NaN
# 146143              NaN             [Documentary]
#
# [146144 rows x 6 columns]

# %%
# Now the genres column will be split by each category
df_x.explode('genres', ignore_index=True)
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0063540                                    Sunghursh
# 2       tt0063540                                    Sunghursh
# 3       tt0066787              One Day Before the Rainy Season
# 4       tt0066787              One Day Before the Rainy Season
# ...           ...                                          ...
# 234953  tt9916538                          Kuambil Lagi Hatiku
# 234954  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 234955  tt9916706                              Dankyavar Danka
# 234956  tt9916730                                       6 Gunn
# 234957  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                         Sunghursh        2013
# 2                                         Sunghursh        2013
# 3                                   Ashad Ka Ek Din        2019
# 4                                   Ashad Ka Ek Din        2019
# ...                                             ...         ...
# 234953                          Kuambil Lagi Hatiku        2019
# 234954  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 234955                              Dankyavar Danka        2013
# 234956                                       6 Gunn        2017
# 234957               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 0                 175.0       Action
# 1                 175.0        Crime
# 2                 175.0        Drama
# 3                 114.0    Biography
# 4                 114.0        Drama
# ...                 ...          ...
# 234953            123.0        Drama
# 234954              NaN  Documentary
# 234955              NaN       Comedy
# 234956            116.0          NaN
# 234957              NaN  Documentary
#
# [234958 rows x 6 columns]

# %%
df_title1=df_x.explode('genres', ignore_index=True)
df_title1.head()
# Out:
#       tconst                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes     genres
# 0            175.0     Action
# 1            175.0      Crime
# 2            175.0      Drama
# 3            114.0  Biography
# 4            114.0      Drama

# %%
# Import the next data base boom.movie
df_boom=pd.read_csv('Documents/Project One/Data/bom.movie_gross.csv')

# %%
# Below we can have the first 5 rows of the data frame
df_boom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Check the dimension of data frames in columns and rows
df_boom.shape
# Out:
# (3387, 5)

# %%
# Check if we have duplicates in our data frame
df_boom.duplicated().value_counts()
# Out:
# False    3387
# Name: count, dtype: int64

# %%
# Below will show the concise summary of data frame
df_boom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# Replace dollar sign and commas for foreign_gross column
df_boom['foreign_gross'] = df_boom['foreign_gross'].str.replace('$', '').str.replace(',', '')

# %%
# Convert the foreign_gross string column to float
df_boom['foreign_gross'] = df_boom['foreign_gross'].astype(float)
df_boom.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
# Create a new column for total revenue, for NAN values we want to sum up as zero values
df_boom['Total Revenue']=df_boom.fillna(0)['domestic_gross']+df_boom.fillna(0)['foreign_gross']
df_boom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year  Total Revenue
# 0    652000000.0  2010   1.067000e+09
# 1    691300000.0  2010   1.025500e+09
# 2    664300000.0  2010   9.603000e+08
# 3    535700000.0  2010   8.283000e+08
# 4    513900000.0  2010   7.526000e+08

# %%
df_boom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   float64
#  4   year            3387 non-null   int64
#  5   Total Revenue   3387 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 158.9+ KB

# %%
# Convert date from integer to date
df_boom['year']=pd.to_datetime(df_boom['year'], format='%Y')

# %%
# Check if the change of date format is made
df_boom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   float64
#  4   year            3387 non-null   datetime64[ns]
#  5   Total Revenue   3387 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 158.9+ KB

# %%
# Format the revenue data in millions (Total Revenue, domestic_gross, foreign_gross)
pd.options.display.float_format = '{:,.2f}'.format
df_boom['Total Revenue'] = df_boom['Total Revenue'] / 1000000 
df_boom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV  415,000,000.00
# 1                   Alice in Wonderland (2010)     BV  334,200,000.00
# 2  Harry Potter and the Deathly Hallows Part 1     WB  296,000,000.00
# 3                                    Inception     WB  292,600,000.00
# 4                          Shrek Forever After   P/DW  238,700,000.00
#
#    foreign_gross       year  Total Revenue
# 0 652,000,000.00 2010-01-01       1,067.00
# 1 691,300,000.00 2010-01-01       1,025.50
# 2 664,300,000.00 2010-01-01         960.30
# 3 535,700,000.00 2010-01-01         828.30
# 4 513,900,000.00 2010-01-01         752.60

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_boom['domestic_gross'] = df_boom['domestic_gross'] / 1000000 
df_boom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV          415.00
# 1                   Alice in Wonderland (2010)     BV          334.20
# 2  Harry Potter and the Deathly Hallows Part 1     WB          296.00
# 3                                    Inception     WB          292.60
# 4                          Shrek Forever After   P/DW          238.70
#
#    foreign_gross       year  Total Revenue
# 0 652,000,000.00 2010-01-01       1,067.00
# 1 691,300,000.00 2010-01-01       1,025.50
# 2 664,300,000.00 2010-01-01         960.30
# 3 535,700,000.00 2010-01-01         828.30
# 4 513,900,000.00 2010-01-01         752.60

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_boom['foreign_gross'] = df_boom['foreign_gross'] / 1000000 
df_boom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV          415.00
# 1                   Alice in Wonderland (2010)     BV          334.20
# 2  Harry Potter and the Deathly Hallows Part 1     WB          296.00
# 3                                    Inception     WB          292.60
# 4                          Shrek Forever After   P/DW          238.70
#
#    foreign_gross       year  Total Revenue
# 0         652.00 2010-01-01       1,067.00
# 1         691.30 2010-01-01       1,025.50
# 2         664.30 2010-01-01         960.30
# 3         535.70 2010-01-01         828.30
# 4         513.90 2010-01-01         752.60

# %%
# Import the next data base boom.movie
df_rate=pd.read_csv('Documents/Project One/Data/title.ratings.csv')

# %%
# Below we can have the first 5 rows of the data frame
df_rate.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526           8.30        31
# 1  tt10384606           8.90       559
# 2   tt1042974           6.40        20
# 3   tt1043726           4.20     50352
# 4   tt1060240           6.50        21

# %%
# Check the dimension of data frames frame in columns and rows
df_rate.shape
# Out:
# (73856, 3)

# %%
# Below will show the concise summary of data frame
df_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
# To merge the two data frames title and boom we have to have the exactly the same name of key columns
df_title1.rename(columns={'primary_title' : 'Title'}, inplace=True)
df_title1.head()
# Out:
#       tconst                            Title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes     genres
# 0           175.00     Action
# 1           175.00      Crime
# 2           175.00      Drama
# 3           114.00  Biography
# 4           114.00      Drama

# %%
df_boom.rename(columns={'title' : 'Title'}, inplace=True)
df_boom.head()
# Out:
#                                          Title studio  domestic_gross  \
# 0                                  Toy Story 3     BV          415.00
# 1                   Alice in Wonderland (2010)     BV          334.20
# 2  Harry Potter and the Deathly Hallows Part 1     WB          296.00
# 3                                    Inception     WB          292.60
# 4                          Shrek Forever After   P/DW          238.70
#
#    foreign_gross       year  Total Revenue
# 0         652.00 2010-01-01       1,067.00
# 1         691.30 2010-01-01       1,025.50
# 2         664.30 2010-01-01         960.30
# 3         535.70 2010-01-01         828.30
# 4         513.90 2010-01-01         752.60

# %%
# Merge two data frames
df_merge=df_title1.merge(df_boom, on='Title', how='inner')
df_merge.head()
# Out:
#       tconst        Title original_title  start_year  runtime_minutes  \
# 0  tt0315642        Wazir          Wazir        2016           103.00
# 1  tt0315642        Wazir          Wazir        2016           103.00
# 2  tt0315642        Wazir          Wazir        2016           103.00
# 3  tt0337692  On the Road    On the Road        2012           124.00
# 4  tt0337692  On the Road    On the Road        2012           124.00
#
#       genres   studio  domestic_gross  foreign_gross       year  Total Revenue
# 0     Action  Relbig.            1.10            NaN 2016-01-01           1.10
# 1      Crime  Relbig.            1.10            NaN 2016-01-01           1.10
# 2      Drama  Relbig.            1.10            NaN 2016-01-01           1.10
# 3  Adventure      IFC            0.74           8.00 2012-01-01           8.74
# 4      Drama      IFC            0.74           8.00 2012-01-01           8.74

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7473 entries, 0 to 7472
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           7473 non-null   object
#  1   Title            7473 non-null   object
#  2   original_title   7473 non-null   object
#  3   start_year       7473 non-null   int64
#  4   runtime_minutes  7264 non-null   float64
#  5   genres           7433 non-null   object
#  6   studio           7467 non-null   object
#  7   domestic_gross   7421 non-null   float64
#  8   foreign_gross    4731 non-null   float64
#  9   year             7473 non-null   datetime64[ns]
#  10  Total Revenue    7473 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 642.3+ KB

# %%
df_merge.describe()
# Out:
#        start_year  runtime_minutes  domestic_gross  foreign_gross  \
# count    7,473.00         7,264.00        7,421.00       4,731.00
# mean     2,013.91           106.67           33.89          83.93
# min      2,010.00             2.00            0.00           0.00
# 25%      2,012.00            94.00            0.17           5.20
# 50%      2,014.00           105.00            2.90          23.10
# 75%      2,016.00           119.00           36.50          87.65
# max      2,020.00           623.00          700.10         946.40
# std          2.51            22.90           70.96         144.79
#
#                                 year  Total Revenue
# count                           7473       7,473.00
# mean   2014-01-26 06:40:48.173424384          86.79
# min              2010-01-01 00:00:00           0.00
# 25%              2012-01-01 00:00:00           0.46
# 50%              2014-01-01 00:00:00           9.60
# 75%              2016-01-01 00:00:00          82.10
# max              2018-01-01 00:00:00       1,405.40
# std                              NaN         184.26

# %%
# Now let's merge the dataframe above with rating dataframe
df_total=df_merge.merge(df_rate, on='tconst', how='left')
df_total.head()
# Out:
#       tconst        Title original_title  start_year  runtime_minutes  \
# 0  tt0315642        Wazir          Wazir        2016           103.00
# 1  tt0315642        Wazir          Wazir        2016           103.00
# 2  tt0315642        Wazir          Wazir        2016           103.00
# 3  tt0337692  On the Road    On the Road        2012           124.00
# 4  tt0337692  On the Road    On the Road        2012           124.00
#
#       genres   studio  domestic_gross  foreign_gross       year  \
# 0     Action  Relbig.            1.10            NaN 2016-01-01
# 1      Crime  Relbig.            1.10            NaN 2016-01-01
# 2      Drama  Relbig.            1.10            NaN 2016-01-01
# 3  Adventure      IFC            0.74           8.00 2012-01-01
# 4      Drama      IFC            0.74           8.00 2012-01-01
#
#    Total Revenue  averagerating  numvotes
# 0           1.10           7.10 15,378.00
# 1           1.10           7.10 15,378.00
# 2           1.10           7.10 15,378.00
# 3           8.74           6.10 37,886.00
# 4           8.74           6.10 37,886.00

# %%
# Drop the column original_title, start_year as we dont need these columns
df_total=df_total.drop('original_title', axis=1)
df_total.head()
# Out:
#       tconst        Title  start_year  runtime_minutes     genres   studio  \
# 0  tt0315642        Wazir        2016           103.00     Action  Relbig.
# 1  tt0315642        Wazir        2016           103.00      Crime  Relbig.
# 2  tt0315642        Wazir        2016           103.00      Drama  Relbig.
# 3  tt0337692  On the Road        2012           124.00  Adventure      IFC
# 4  tt0337692  On the Road        2012           124.00      Drama      IFC
#
#    domestic_gross  foreign_gross       year  Total Revenue  averagerating  \
# 0            1.10            NaN 2016-01-01           1.10           7.10
# 1            1.10            NaN 2016-01-01           1.10           7.10
# 2            1.10            NaN 2016-01-01           1.10           7.10
# 3            0.74           8.00 2012-01-01           8.74           6.10
# 4            0.74           8.00 2012-01-01           8.74           6.10
#
#    numvotes
# 0 15,378.00
# 1 15,378.00
# 2 15,378.00
# 3 37,886.00
# 4 37,886.00

# %%
df_total=df_total.drop('start_year', axis=1)
df_total.head()
# Out:
#       tconst        Title  runtime_minutes     genres   studio  \
# 0  tt0315642        Wazir           103.00     Action  Relbig.
# 1  tt0315642        Wazir           103.00      Crime  Relbig.
# 2  tt0315642        Wazir           103.00      Drama  Relbig.
# 3  tt0337692  On the Road           124.00  Adventure      IFC
# 4  tt0337692  On the Road           124.00      Drama      IFC
#
#    domestic_gross  foreign_gross       year  Total Revenue  averagerating  \
# 0            1.10            NaN 2016-01-01           1.10           7.10
# 1            1.10            NaN 2016-01-01           1.10           7.10
# 2            1.10            NaN 2016-01-01           1.10           7.10
# 3            0.74           8.00 2012-01-01           8.74           6.10
# 4            0.74           8.00 2012-01-01           8.74           6.10
#
#    numvotes
# 0 15,378.00
# 1 15,378.00
# 2 15,378.00
# 3 37,886.00
# 4 37,886.00

# %%
# Check the info of the new database
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7473 entries, 0 to 7472
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           7473 non-null   object
#  1   Title            7473 non-null   object
#  2   runtime_minutes  7264 non-null   float64
#  3   genres           7433 non-null   object
#  4   studio           7467 non-null   object
#  5   domestic_gross   7421 non-null   float64
#  6   foreign_gross    4731 non-null   float64
#  7   year             7473 non-null   datetime64[ns]
#  8   Total Revenue    7473 non-null   float64
#  9   averagerating    6987 non-null   float64
#  10  numvotes         6987 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 642.3+ KB

# %%
# Check the statistics data of dataframe
df_total.describe()
# Out:
#        runtime_minutes  domestic_gross  foreign_gross  \
# count         7,264.00        7,421.00       4,731.00
# mean            106.67           33.89          83.93
# min               2.00            0.00           0.00
# 25%              94.00            0.17           5.20
# 50%             105.00            2.90          23.10
# 75%             119.00           36.50          87.65
# max             623.00          700.10         946.40
# std              22.90           70.96         144.79
#
#                                 year  Total Revenue  averagerating  \
# count                           7473       7,473.00       6,987.00
# mean   2014-01-26 06:40:48.173424384          86.79           6.45
# min              2010-01-01 00:00:00           0.00           1.60
# 25%              2012-01-01 00:00:00           0.46           5.90
# 50%              2014-01-01 00:00:00           9.60           6.50
# 75%              2016-01-01 00:00:00          82.10           7.10
# max              2018-01-01 00:00:00       1,405.40           9.20
# std                              NaN         184.26           0.99
#
#           numvotes
# count     6,987.00
# mean     72,041.77
# min           5.00
# 25%       3,789.00
# 50%      18,928.00
# 75%      78,184.00
# max   1,841,066.00
# std     134,929.27

# %%
# Lets have a look at the data we have
# Create histogram for total Revenue
sns.histplot(data=df_total, x="Total Revenue", kde=True, bins=5)
sns.set_theme(style='dark', font_scale=1)
# The data for total revenue are not normally distributed but left skewed

# %%
# The correlation between total revenue and average ratings
import seaborn as sns
sns.scatterplot(data=df_total, x="Total Revenue", y="averagerating")
sns.set_theme(style='whitegrid', font_scale=1)

# %%
# Lets have a look ate the correlation between num of votes and average ratings
sns.scatterplot(data=df_total, x="numvotes", y="averagerating")
sns.set_theme(style='dark', font_scale=1)

# %%
# Lets have a look ate the correlation between num of votes and Total Revenue(No correlation)
sns.scatterplot(data=df_total, y="numvotes", x="Total Revenue")
sns.set_theme(style='darkgrid', font_scale=1)

# %%
# We will find top ten movies according total revenue
df11=df_boom.groupby('Title')['Total Revenue'].sum().reset_index()
df12=df11.sort_values('Total Revenue', ascending=False)
df12
# Out:
#                                             Title  Total Revenue
# 1622                        Marvel's The Avengers       1,518.90
# 274                       Avengers: Age of Ultron       1,405.40
# 387                                 Black Panther       1,347.00
# 1065  Harry Potter and the Deathly Hallows Part 2       1,341.50
# 2317                     Star Wars: The Last Jedi       1,332.60
# ...                                           ...            ...
# 31                                           2:22           0.00
# 2160                                      Satanic           0.00
# 1793                        News From Planet Mars           0.00
# 2512                              The Chambermaid           0.00
# 2336                                   Storage 24           0.00
#
# [3386 rows x 2 columns]

# %%
# Reset the index of dataframe
df13=df12.reset_index(drop=True)
df13
# Out:
#                                             Title  Total Revenue
# 0                           Marvel's The Avengers       1,518.90
# 1                         Avengers: Age of Ultron       1,405.40
# 2                                   Black Panther       1,347.00
# 3     Harry Potter and the Deathly Hallows Part 2       1,341.50
# 4                        Star Wars: The Last Jedi       1,332.60
# ...                                           ...            ...
# 3381                                         2:22           0.00
# 3382                                      Satanic           0.00
# 3383                        News From Planet Mars           0.00
# 3384                              The Chambermaid           0.00
# 3385                                   Storage 24           0.00
#
# [3386 rows x 2 columns]

# %%
# Filter top ten Movie titles and revenue
df_top_tenmovies=df13.iloc[0:9]
df_top_tenmovies
# Out:
#                                          Title  Total Revenue
# 0                        Marvel's The Avengers       1,518.90
# 1                      Avengers: Age of Ultron       1,405.40
# 2                                Black Panther       1,347.00
# 3  Harry Potter and the Deathly Hallows Part 2       1,341.50
# 4                     Star Wars: The Last Jedi       1,332.60
# 5               Jurassic World: Fallen Kingdom       1,309.50
# 6                                       Frozen       1,276.40
# 7                  Beauty and the Beast (2017)       1,263.50
# 8                                Incredibles 2       1,242.80

# %%
# Vizualise the top ten movies by total Revenue in graph
sns.barplot(data=df_top_tenmovies, x="Total Revenue", y="Title").set_title('Top-10 Movies by revenues')
sns.set_theme(style='darkgrid', font_scale=1)

# %%
# Now we will prepare the three insight for Windows Company
# Group the Genres by total revenue to define top ten genres by revenue
df2=df_total.groupby('genres')['Total Revenue'].sum().reset_index()
df3=df2.sort_values('Total Revenue', ascending=False)
df3
# Out:
#          genres  Total Revenue
# 1     Adventure     119,967.20
# 0        Action     107,443.34
# 4        Comedy      78,896.08
# 7         Drama      73,680.58
# 2     Animation      39,493.40
# 17       Sci-Fi      38,638.41
# 19     Thriller      35,494.72
# 9       Fantasy      27,900.72
# 5         Crime      19,479.89
# 16      Romance      16,599.41
# 11       Horror      16,340.07
# 3     Biography      14,053.71
# 8        Family      13,956.80
# 14      Mystery      12,221.64
# 6   Documentary      11,542.73
# 10      History       6,685.62
# 18        Sport       4,441.20
# 12        Music       3,888.72
# 13      Musical       1,292.04
# 21      Western       1,231.31
# 20          War         864.42
# 15         News          69.85

# %%
#  Create a new data set with genres, total revenue and year column
new_dataset = df_total.loc[:, ['genres','Total Revenue', 'year']]
new_dataset.head()
# Out:
#       genres  Total Revenue       year
# 0     Action           1.10 2016-01-01
# 1      Crime           1.10 2016-01-01
# 2      Drama           1.10 2016-01-01
# 3  Adventure           8.74 2012-01-01
# 4      Drama           8.74 2012-01-01

# %%
# Cretate a new dataset from the new_dataset with data for years 2015-2018
df_genres_year=new_dataset.loc[new_dataset['year'] >= '2015']
df_genres_year
# Out:
#            genres  Total Revenue       year
# 0          Action           1.10 2016-01-01
# 1           Crime           1.10 2016-01-01
# 2           Drama           1.10 2016-01-01
# 17         Action         652.30 2015-01-01
# 18      Adventure         652.30 2015-01-01
# ...           ...            ...        ...
# 7466        Drama           0.07 2018-01-01
# 7469        Drama           0.18 2018-01-01
# 7470      Romance           0.18 2018-01-01
# 7471  Documentary          20.30 2018-01-01
# 7472        Music          20.30 2018-01-01
#
# [3488 rows x 3 columns]

# %%
# Create a new dataframe for top ten genres acording the total revenue
df_topgenres=df_genres_year.loc[df_genres_year ['genres'].isin(['Action', 'Comedy', 'Drama', 'Animation', 'Sci-Fi', 'Thriller', 'Fantasy', 'Crime', 'Romance'])]
df_topgenres.head()
# Out:
#     genres  Total Revenue       year
# 0   Action           1.10 2016-01-01
# 1    Crime           1.10 2016-01-01
# 2    Drama           1.10 2016-01-01
# 17  Action         652.30 2015-01-01
# 19  Sci-Fi         652.30 2015-01-01

# %%
# Visualize the data in a lineplot
sns.lineplot(data=df_topgenres, x="year", y="Total Revenue", hue="genres", style="genres", errorbar=None).set_title('Total Revenue by Genres for the last 5 years')
sns.set_theme(style='darkgrid', font_scale=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
# Group the Genres by average ratings
df5=df_total.groupby('genres')['averagerating'].mean().reset_index()
df6=df5.sort_values('averagerating', ascending=False)
df6
# Out:
#          genres  averagerating
# 6   Documentary           7.29
# 15         News           7.10
# 3     Biography           6.97
# 10      History           6.88
# 18        Sport           6.87
# 20          War           6.80
# 12        Music           6.76
# 2     Animation           6.70
# 7         Drama           6.59
# 21      Western           6.56
# 5         Crime           6.48
# 1     Adventure           6.48
# 17       Sci-Fi           6.45
# 16      Romance           6.34
# 13      Musical           6.32
# 0        Action           6.28
# 14      Mystery           6.27
# 4        Comedy           6.25
# 9       Fantasy           6.24
# 8        Family           6.22
# 19     Thriller           6.17
# 11       Horror           5.68

# %%
# Reset the index
df7=df6.reset_index(drop=True)
df7
# Out:
#          genres  averagerating
# 0   Documentary           7.29
# 1          News           7.10
# 2     Biography           6.97
# 3       History           6.88
# 4         Sport           6.87
# 5           War           6.80
# 6         Music           6.76
# 7     Animation           6.70
# 8         Drama           6.59
# 9       Western           6.56
# 10        Crime           6.48
# 11    Adventure           6.48
# 12       Sci-Fi           6.45
# 13      Romance           6.34
# 14      Musical           6.32
# 15       Action           6.28
# 16      Mystery           6.27
# 17       Comedy           6.25
# 18      Fantasy           6.24
# 19       Family           6.22
# 20     Thriller           6.17
# 21       Horror           5.68

# %%
# Filter top ten genres and averating
df_gen_avrating=df7.iloc[0:9]
df_gen_avrating
# Out:
#         genres  averagerating
# 0  Documentary           7.29
# 1         News           7.10
# 2    Biography           6.97
# 3      History           6.88
# 4        Sport           6.87
# 5          War           6.80
# 6        Music           6.76
# 7    Animation           6.70
# 8        Drama           6.59

# %%
# Visualize the top ten genres by average rating in a bar graph
sns.barplot(data=df_gen_avrating, x="averagerating", y="genres").set_title('Average Rating by Genres')
# Out:
# Text(0.5, 1.0, 'Average Rating by Genres')

# %%
# Group the studios by total revenue
df8=df_boom.groupby('studio')['Total Revenue'].sum().reset_index()
df9=df8.sort_values('Total Revenue', ascending=False)
df9
# Out:
#          studio  Total Revenue
# 36           BV      44,212.88
# 93          Fox      31,005.37
# 246          WB      30,835.95
# 238        Uni.      29,757.16
# 215        Sony      22,405.04
# ..          ...            ...
# 34          BSM           0.01
# 224        TAFC           0.00
# 111       Hiber           0.00
# 6           ALP           0.00
# 222  Synergetic           0.00
#
# [257 rows x 2 columns]

# %%
# Reset the index
df10=df9.reset_index(drop=True)
df10
# Out:
#          studio  Total Revenue
# 0            BV      44,212.88
# 1           Fox      31,005.37
# 2            WB      30,835.95
# 3          Uni.      29,757.16
# 4          Sony      22,405.04
# ..          ...            ...
# 252         BSM           0.01
# 253        TAFC           0.00
# 254       Hiber           0.00
# 255         ALP           0.00
# 256  Synergetic           0.00
#
# [257 rows x 2 columns]

# %%
# Show top ten studios and total revenue
df_studio_rev=df10.iloc[0:9]
df_studio_rev
# Out:
#     studio  Total Revenue
# 0       BV      44,212.88
# 1      Fox      31,005.37
# 2       WB      30,835.95
# 3     Uni.      29,757.16
# 4     Sony      22,405.04
# 5     Par.      19,549.26
# 6  WB (NL)      10,334.70
# 7      LGF       8,601.58
# 8     LG/S       5,431.92

# %%
# Visualize the top ten studios by total revenue in a bar graph
sns.barplot(data=df_studio_rev, x="Total Revenue", y="studio").set_title('Total Revenue by Studio')
# Out:
# Text(0.5, 1.0, 'Total Revenue by Studio')
